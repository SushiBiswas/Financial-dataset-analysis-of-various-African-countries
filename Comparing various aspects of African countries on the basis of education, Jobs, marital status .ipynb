# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Financial Dataset - 1.csv')

# %%
df
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has a Bank account      23488 non-null  object
#  4   Type of Location        23509 non-null  object
#  5   Cell Phone Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The relathip with head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level of Educuation     23495 non-null  object
#  12  Type of Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# country                   14
# year                       0
# uniqueid                   0
# Has a Bank account        36
# Type of Location          15
# Cell Phone Access         11
# household_size            28
# Respondent Age            34
# gender_of_respondent      34
# The relathip with head     4
# marital_status            32
# Level of Educuation       29
# Type of Job               30
# dtype: int64

# %%
df.shape
# Out:
# (23524, 13)

# %%
df.drop_duplicates()
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
df.shape
# Out:
# (23524, 13)

# %%
for i in df.columns:
    print (i, "-", df[i].nunique())
# Out:
# country - 4
# year - 6
# uniqueid - 8735
# Has a Bank account - 2
# Type of Location - 2
# Cell Phone Access - 2
# household_size - 21
# Respondent Age - 85
# gender_of_respondent - 2
# The relathip with head - 6
# marital_status - 5
# Level of Educuation - 7
# Type of Job - 10

# %%
plt.figure(figsize = (6,6))
sns.countplot(data = df, x = 'gender_of_respondent')
plt.title("Gender distribution")
plt.show()

# %%
plt.figure(figsize = (6,6))
sns.countplot(data = df, x = 'country')
plt.title('Country wise distribution')
plt.show()

# %%
df
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
plt.figure(figsize = (10,6))
sns.countplot(data = df, x = 'marital_status')
plt.title('marital status wise distribution')
plt.show()

# %%
plt.figure(figsize = (20,6))
sns.countplot(data = df, x = 'Level of Educuation')
plt.title('Educuation wise distribution')
plt.show()

# %%
plt.figure(figsize = (25,6))
sns.countplot(data = df, x = 'Type of Job')
plt.title('Job wise distribution')
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(data = df, x = 'The relathip with head')
plt.title('various types of the Customer’s Relationship with the head')
plt.show()

# %%
df
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 0       Kenya  2018     uniqueid_1                Yes            Rural
# 1       Kenya  2018     uniqueid_2                 No            Rural
# 2       Kenya  2018     uniqueid_3                Yes            Urban
# 3       Kenya  2018     uniqueid_4                 No            Rural
# 4       Kenya  2018     uniqueid_5                 No            Urban
# ...       ...   ...            ...                ...              ...
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# ...

# %%
plt.figure(figsize = (10,6))
sns.countplot(data = df, x = 'Respondent Age')
plt.title('Age wise distribution')
plt.show()

# %%
sns.histplot(df['Respondent Age'])
# Out:
# <Axes: xlabel='Respondent Age', ylabel='Count'>

# %%
age_column = df['Respondent Age']

# %%
total_values = age_column.count()

# %%
# Median
median_age = age_column.median()

# Mean
mean_age = age_column.mean()

# Minimum and Maximum values
min_age = age_column.min()
max_age = age_column.max()

# Standard variance
std_variance = age_column.std()

# Quartiles (25%, 50%, 75%)
quartiles = age_column.quantile([0.25, 0.5, 0.75])

print("Count of total values:", total_values)
print("Median:", median_age)
print("Mean:", mean_age)
print("Minimum value:", min_age)
print("Maximum value:", max_age)
print("Standard variance:", std_variance)
print("Quartiles (25%, 50%, 75%):")
print(quartiles)
# Out:
# Count of total values: 23490
# Median: 35.0
# Mean: 38.804299702000854
# Minimum value: 16.0
# Maximum value: 100.0
# Standard variance: 16.51999610879876
# Quartiles (25%, 50%, 75%):
# 0.25    26.0
# 0.50    35.0
# 0.75    49.0
# Name: Respondent Age, dtype: float64
